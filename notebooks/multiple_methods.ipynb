# %%
'''
This expirment combine all the agumentations methods that yiled posetive and stable results (cutmix,permutation,jitter) with the best parmeters(cutmix_alpha=0.2,permutation=4,jitte=0.01
'''
import sys
sys.path.append("..")
from src.experiments.base_experiment_utils import run_experiment
run_experiment(
        results_dir=f"../results/multiple_methods",
        augmentation_type='multiple_methods',
        jitter_std=0.01,permute_segments=4,cutmix_alpha=0.2
    )
# Out:
# Processing Record: ../bidmc/bidmc01
# Record ../bidmc/bidmc01 --> RMSE: 0.1587, Pearson r: 0.7616
# Saved model to ../results/multiple_methods/base_model_.._bidmc_bidmc01.pt
# Saved training plot to ../results/multiple_methods/base_model_.._bidmc_bidmc01.png
# Processing Record: ../bidmc/bidmc02
# Record ../bidmc/bidmc02 --> RMSE: 0.0681, Pearson r: 0.5979
# Saved model to ../results/multiple_methods/base_model_.._bidmc_bidmc02.pt
# Saved training plot to ../results/multiple_methods/base_model_.._bidmc_bidmc02.png
# Processing Record: ../bidmc/bidmc03
# Record ../bidmc/bidmc03 --> RMSE: 0.0380, Pearson r: 0.7489
# Saved model to ../results/multiple_methods/base_model_.._bidmc_bidmc03.pt
# Saved training plot to ../results/multiple_methods/base_model_.._bidmc_bidmc03.png
# Processing Record: ../bidmc/bidmc04
# Record ../bidmc/bidmc04 --> RMSE: 0.0725, Pearson r: 0.4846
# Saved model to ../results/multiple_methods/base_model_.._bidmc_bidmc04.pt
# ...
